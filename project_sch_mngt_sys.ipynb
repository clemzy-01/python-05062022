# %%
# STUDENT MANAGEMENT SYSTEM

# CREATE CLASS "STUDENT"

class Student:
    
    # Constructor
    
    def __init__ (self,Name,Age,Gender,Date_of_birth,Seat_Number):
        self.Name = Name
        self.Age = Age
        self.Gender = Gender
        self.Date_of_birth = Date_of_birth
        self.Seat_Number = Seat_Number
        
        
        
    # Funtion to append and create student details
    
    def accept(self,NAME,AGE,GENDER,DATE_OF_BIRTH,SEAT_NUMBER):
        obj = Student(NAME,AGE,GENDER,DATE_OF_BIRTH,SEAT_NUMBER)
        Student_list.append(obj)
        
        
    # funtion to display student details
    def display(self , obj):
        print("Name  : ", obj.Name)
        print("Age  : ", obj.Age)
        print("Gender  : ", obj.Gender)
        print("Date_of_birth  : ", obj.Date_of_birth)
        print("Seat_Number  : ", obj.Seat_Number)
        print("\n")
        
        
        
    # funtion to search for a student
    
    def search(self, n):
        for i in range(Student_list.__len__()):
            if (Student_list[i].Name == n):
                return i
            
            
    # Function to delete student details
    
    def delete(self , n):
        i = obj.search(n)
        del Student_list[i]
        
        
        
    # funtion to update Student 
    
    def update(self , n , No):
        i = obj.search(n)
        NAME = No
        Student_list[i].Name = NAME;
        
        
        
        
# creating list to append student data
Student_list = []
# object of student class
obj = Student(' ', 0 ,' ', 0 , 0)



# Displaying operational options

print("\nOperations Used,  ")
print('''\n1.Accept Student Details\n2.Display Student Details
3.Search Details of a Student\n4.Delete details of Student
5.Update Student Details\n6.Exit
''')


# Prompting user to input an operation number
x = input('enter Y to edit details and N to quit :')
x = x.upper()


# conditions
while x == 'Y':
    ch = int(input("Enter your operation command : "))
    if (ch == 1):
        obj.accept('Ada', 18 ,'F',2014_06_28, 1)
        obj.accept('Sophia', 20 ,'F',1998_01_14, 2)
        obj.accept('Peter', 21 ,'M',1999_06_28, 3)
        obj.accept('Clement', 21 ,'M',1990_06_24, 4)
        
        
    elif (ch == 2):
        print('\n')
        print('\nList of Students\n')
        for i in range(Student_list.__len__()):
            obj.display(Student_list[i])
        
    elif (ch == 3):
        print('\n Student Found, ')
        n = obj.search('Ada')
        obj.display(Student_list[n])
       
    elif (ch == 4):
        obj.delete('Clement')
        print(Student_list.__len__())
        print('List after deletion')
        for i in range(Student_list.__len__()):
            obj.display(Student_list[i])
        
    elif (ch == 5):
        obj.update('Peter','Peterson')
        print(Student_list.__len__())
        print('List after updation')
        for i in range(Student_list.__len__()):
            obj.display(Student_list[i])
            
            
            
    else :
        print("Please enter a valid operation number")
        
        
    x = input('enter Y to edit details and N to quit :')
    x = x.upper()
    ch = int(input("Enter your operation command : "))
    
    
n= 1        
print("Thank you")
# Out:
# Operations Used,
#
# 1.Accept Student Details
# 2.Display Student Details
# 3.Search Details of a Student
# 4.Delete details of Student
# 5.Update Student Details
# 6.Exit
#
# enter Y to edit details and N to quit :y
# Enter your operation command : 1
# enter Y to edit details and N to quit :y
# Enter your operation command : 2
# Enter your operation command : 2
#
#
#
# List of Students
#
# Name  :  Ada
# Age  :  18
# Gender  :  F
# Date_of_birth  :  20140628
# Seat_Number  :  1
#
#
# Name  :  Sophia
# Age  :  20
# Gender  :  F
# Date_of_birth  :  19980114
# Seat_Number  :  2
#
#
# Name  :  Peter
# Age  :  21
# Gender  :  M
# Date_of_birth  :  19990628
# Seat_Number  :  3
#
#
# Name  :  Clement
# Age  :  21
# Gender  :  M
# Date_of_birth  :  19900624
# Seat_Number  :  4
#
#
# enter Y to edit details and N to quit :y
# Enter your operation command : 3
# Enter your operation command : 3
#
#  Student Found,
# Name  :  Ada
# Age  :  18
# Gender  :  F
# Date_of_birth  :  20140628
# ...
