# %%
## Using Class and Object, build a patient management system with the following attributes
# 1. Name 2. Age 3. Gender 4.DOB 5. Address 6. Hospital number 
# with the following Accept, Display, Search, Update, Delete

class Patient_Management_System:
    
    '''A Patient Management Systemsing Class and Object'''
      
    def __init__(self,Name,Age,Gender,DOB,Address,Hospital_Number):
        self.Name = Name
        self.Age = Age
        self.Gender = Gender
        self.DOB = DOB
        self.Address = Address
        self.Hospital_Number = Hospital_Number
        
        
    #A Method to Accept New Patients and append them to a list  
    
    def accept(self,NAME,AGE,GENDER,DOB,ADDRESS,HOSPITAL_NUMBER):
        hos = Patient_Management_System(NAME,AGE,GENDER,DOB,ADDRESS,HOSPITAL_NUMBER)
        patient_list.append(hos)
                 
                         
    #A Method to display Patient's information
    
    def display(self):
        print('============== PATIENT INFORMATION ===============')
        print('Patient details: ')
        print('Patient\'s Name: ',hos.Name)
        print('Patient\'s Age: ',hos.Age)
        print('Patient\'s Gender: ',hos.Gender)
        print('Patient\'s DOB: ',hos.DOB)
        print('Patient\'s Address: ',hos.Address)
        print('Patient\'s Hospital Number: ',hos.Hospital_Number)
        
    #A Method to search the list for a Patient's Info
    
    def search(self, n):
        for x in range(patient_list.__len__()):
            if (patient_list[x].Name == n):
                return x
                
     #A method to Delete Patient information
    def delete(self, n):
        i = hos.search(n)
        del patient_list[i]
        
    #A Method to Update a patient's list
    def update(self, n, Na):
        i = hos.search(n)
        NAME = Na
        patient_list[i].Name = NAME
 

    #An object of Patient_Management_System Class
patient_list = []
hos = Patient_Management_System('',0,'',0,'',0)

#Display Options for prompt guide
print('\nSELECT OPERATION YOU WISH TO PERFORM')
print('''\n1. Accept Patient Details
2. Display Patient Details
3. Search Patient Info from Patient List
4. Delete Patient Info from List
5. Update Patient Info on list
6. Exit
''')

#Enabling User to Choose an Operation
x = input('Please enter Y to edit details or N to Exit: ')
x = x.upper()

while x == 'Y':
    choice = int(input('Enter Operation No.: '))
    if (choice == 1):
        hos.accept('Ade',22,'M',10_09_2000,'4 Anisi Street, Kubwa',1)
        hos.accept('Ayo',23,'M',18_03_1999,'34 Oju Crescent, Kubwa',2)
        hos.accept('Folu',21,'F',13_01_2001,'5 Obiano Street, Kubwa',3)
        hos.accept('Faith',24,'F',22_10_1998,'90 Gado Nasco Road, Kubwa',4)
                     
    if (choice == 2):
        print('\n')
        print('\nList of Patients\n')
        for i in range(patient_list.__len__()):
            hos.display(patient_list[i])
    if (choice == 3):
        print('\nPatient Detail found: ')
        n = hos.search('Ayo')
        hos.display(patient_list[n])
        
    if (choice == 4):
        hos.delete('Folu')
        print(patient_list.__len__())
        print('List of Patients after delete has been executed')
        for i in range(patient_list.__len__()):
            hos.display(patient[i])
            
    if (choice == 5):
        hos.update('Ade','Kalu')
        print(patient_list.__len__())
        print('List of Patients after update has been executed')
        for i in range(patient_list.__len__()):
            hos.display(patient[i])
        
    else:
        print('Please enter a valid Operation Number!!!')
    
    x = input('Please enter Y to edit details or N to Exit: ')
    x = x.upper()
    choice = int(input('Enter Operation No.: '))
    
n = 1
# Out:
# SELECT OPERATION YOU WISH TO PERFORM
#
# 1. Accept Patient Details
# 2. Display Patient Details
# 3. Search Patient Info from Patient List
# 4. Delete Patient Info from List
# 5. Update Patient Info on list
# 6. Exit
#
# Please enter Y to edit details or N to Exit: Y
# Enter Operation No.: 1
# Please enter a valid Operation Number!!!

# %%
## Using Class and Object, build a patient management system with the following attributes
# 1. Name 2. Age 3. Gender 4.DOB 5. Address 6. Hospital number 
# with the following Accept, inputdata, Display, Search, Update, Delete

class Patient_Management_System:
    '''A Patient Management System'''
    def __init__(self,Hospital_Number=0,Name='',Age=0,Gender='',DOB=0,Address=''):
        self.Name = Name
        self.Age = Age
        self.Gender = Gender
        self.DOB = DOB
        self.Address = Address
        self.Hospital_Number = Hospital_Number
    
    #defining the method to input data 
    def inputdata(self):
        print('\nPLEASE ENTER PATIENT\'s DATA')
        self.Hospital_Number=input("\nEnter Hospital No.: ")
        self.Name=input("\nEnter Fullname: ")
        self.Age=input("\nEnter Age in years: ")
        self.Gender=input("\nEnter Gender: ")
        self.DOB=input("\nEnter DOB as dd_mm_yyyy:")
        self.Address=input("\nEnter your address:")
        
    def accept(self,Hospital_Number,Name,Age,Gender,DOB,Address):
        hos = self.inputdata
        patient_list.append(hos)
    
    #defining method to display patient's information   
    def display(self,hos):
        print('=======PATIENT DETAILS======')
        print('Patient\'s Hospital Number: ',hos.Hospital_Number)
        print('Patient\'s Name: ',hos.Name)
        print('Patient\'s Age: ',hos.Age)
        print('Patient\'s Gender as M or F: ',hos.Gender)
        print('Patient\'s DOB: ',hos.DOB)
        print('Patient\'s Address: ',hos.Address)
        print('\n')
    #definging method to search for patient's info
    def search(self,hn):
        for i in range(patient_list.__len__()):
            if (patient_list[i].Hospital_Number == hn):
                return i
                
    #A method to Delete Patient information
    def delete(self, hn):
        i = hos.search(hn)
        del patient_list[i]
        
    
    #A Method to Update a patient's list
    def update(self, hn, Hn):
        i = hos.search(hn)
        HOSPITAL_NUMBER = Hn
        patient_list[i].Hospital_Number = HOSPITAL_NUMBER
 
    #An object of Patient_Management_System Class
patient_list = []
hos = Patient_Management_System()

#Display Options for prompt guide
print('\nSELECT OPERATION YOU WISH TO PERFORM')
print('''\n1. Accept Patient Details
2. Display Patient Details
3. Search Patient Info from Patient List
4. Delete Patient Info from List
5. Update Patient Info on list
6. Exit
''')

#Enabling User to Choose an Operation
x = input('Please enter Y to edit details or N to Exit: ')
x = x.upper()

while x == 'Y':
    choice = int(input('Enter Operation No.: '))
    if (choice == 1):
        hos.inputdata()
        hos.accept.inputdata()
        hos.display(hos)
                
    elif (choice == 2):
        print('\n')
        print('\nList of Patients\n')
        for i in range(patient_list.__len__()):
            hos.display(patient_list[i])
    
    elif (choice == 3):
        print('\nPatient Detail found: ')
        hn = hos.search(101)
        hos.display(patient_list[hn]) 
        
    elif (choice == 4):
        hos.delete(102)
        print(patient_list.__len__())
        print('List of Patients after delete has been executed')
        for i in range(patient_list.__len__()):
            hos.display(patient_list[i])
            
    elif (choice == 5):
        hos.update(101,110)
        print(patient_list.__len__())
        print('List of Patients after update has been executed')
        for i in range(patient_list.__len__()):
            hos.display(patient_list[i])
    elif (choice == 6):
        print('\nExit')
        print('\n')
        print('THANK YOU')
    else:
        print('Please enter a valid Operation Number!!!')
    
    x = input('Please enter Y to edit details or N to Exit: ')
    x = x.upper()
    choice = int(input('Enter Operation No.: '))
    
n = 1
print('THANK YOU!!')
# Out:
# SELECT OPERATION YOU WISH TO PERFORM
#
# 1. Accept Patient Details
# 2. Display Patient Details
# 3. Search Patient Info from Patient List
# 4. Delete Patient Info from List
# 5. Update Patient Info on list
# 6. Exit
#
# Please enter Y to edit details or N to Exit: Y
# Enter Operation No.: 1
#
# PLEASE ENTER PATIENT's DATA
#
# Enter Hospital No.: 102
#
# Enter Fullname: Devin
#
# Enter Age in years: 23
#
# Enter Gender: M
#
# Enter DOB as dd_mm_yyyy:10_2_1999
#
# Enter your address:34 juloma street
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d6ac90566588> in <module>
#      77     if (choice == 1):
#      78         hos.inputdata()
# ---> 79         hos.accept.inputdata()
#      80         hos.display(hos)
#      81
#
# AttributeError: 'function' object has no attribute 'inputdata'

# %%
#defining method to accept patient info    
def accept(rec,Hospital_Number,Name,Age,Gender,DOB,Address):
        rec.append(Patient_Management_System(Hospital_Number,Name,Age,Gender,DOB,Address))
        return rec
