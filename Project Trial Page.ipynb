# %%
### Using Class and Object, build a patient management system with the following attributes
# 1. Name 2. Age 3. Gender 4.DOB 5. Address 6. Hospital number 
# with the following Accept, Display, Search, Update, Delete

class Patient_Management_System:
      
    def __init__(self,Name='',Age='',Gender='',DOB='',Address='',Hospital_Number=''):
        '''A Patient Management Systemsing Class and Object'''
        self.Name = Name
        self.Age = Age
        self.Gender = Gender
        self.DOB = DOB
        self.Address = Address
        self.Hospital_Number = Hospital_Number
        
    def accept(self):
        self.Name = input('\nEnter your Fullname: ')
        self.Age = int(input('\nEnter your Age in years: '))
        self.Gender = input('\nEnter your Gender (M or F): ')
        self.DOB = input('\nEnter your DOB as dd/mm/yyy: ')
        self.Address = input('\nEnter your Address: ')
        self.Hospital_Number = input('Enter Hospital Number using the format (HMB/DN/CN): ')
                         

    def display(self):
        print('============== PATIENT INFORMATION ===============')
        print('Patient details: ')
        print('Patient\'s Name: ',self.Name)
        print('Patient\'s Age: ',self.Age)
        print('Patient\'s Gender: ',self.Gender)
        print('Patient\'s DOB: ',self.DOB)
        print('Patient\'s Address: ',self.Address)
        print('Patient\'s Hospital Number: ',self.Hospital_Number)
        
                           
    def search(self, Hospital_Number):
            l = []
            readfile(patient_list)
            for x in patient_list:
                y = x.search()
                if y == Hospital_Number:
                    l.append(x.printobject())
            return l
    
        
def main():
    a = Patient_Management_System()
    
    while (1):
        print('1. Enter Details to Accept Patient')
        print('2. Display Patient Details')
        print('3. Search Patient Info from Patient List')
        print('4. Delete Patient Info from List')
        print('5. Exit')
        
        b = int(input('\nEnter the number of your choice: '))
        if (b == 1):
            a.accept()
        if (b == 2):
            a.display()
        if (b == 3):
            a.search()
        if (b == 4):
            a.Delete()
        if (b == 5):
            quit()

            
def storage(rec,Name,Age, Gender, DOB,Hospital_Number):
    rec.append(Patient_Management_System(rec,Name,Age, Gender, DOB,Hospital_Number))
    return rec
record = []

main()
# Out:
# 1. Enter Details to Accept Patient
# 2. Display Patient Details
# 3. Search Patient Info from Patient List
# 4. Delete Patient Info from List
# 5. Exit
#
# Enter the number of your choice: 1
#
# Enter your Fullname: Chi Ade
#
# Enter your Age in years: 22
#
# Enter your Gender (M or F): F
#
# Enter your DOB as dd/mm/yyy: 12/02/2000
#
# Enter your Address: 23 oki street
# Enter Hospital Number using the format (HMB/DN/CN): HMB/01/20
# 1. Enter Details to Accept Patient
# 2. Display Patient Details
# 3. Search Patient Info from Patient List
# 4. Delete Patient Info from List
# 5. Exit
#
# Enter the number of your choice: 1
#
# Enter your Fullname: Chi Oni
#
# Enter your Age in years: 22
#
# Enter your Gender (M or F): F
#
# Enter your DOB as dd/mm/yyy: 13/04/2000
#
# Enter your Address: 12 this street
# Enter Hospital Number using the format (HMB/DN/CN): HMB/02/134
# 1. Enter Details to Accept Patient
# 2. Display Patient Details
# 3. Search Patient Info from Patient List
# ...

# %%
for i in range(len(record)):
    accept.display(record[i])

# %%
### Using Class and Object, build a patient management system with the following attributes
# 1. Name 2. Age 3. Gender 4.DOB 5. Address 6. Hospital number 
# with the following Accept, Display, Search, Update, Delete

class Patient_Management_System:
    
    '''A Patient Management Systemsing Class and Object'''
      
    def __init__(self,Name='',Age='',Gender='',DOB='',Address='',Hospital_Number=''):
        self.Name = Name
        self.Age = Age
        self.Gender = Gender
        self.DOB = DOB
        self.Address = Address
        self.Hospital_Number = Hospital_Number
        
        
    #A Method to Accept New Patients and append them to a list  
    
    def accept(self,NAME,AGE,GENDER,DOB,ADDRESS,HOSPITAL_NUMBER):
        hos = Patient_Management_System(self,NAME,AGE,GENDER,DOB,ADDRESS,HOSPITAL_NUMBER)
        patient_list.append(hos)
                 
                         
    #A Method to display Patient's information
    
    def display(self):
        print('============== PATIENT INFORMATION ===============')
        print('Patient details: ')
        print('Patient\'s Name: ',hos.Name)
        print('Patient\'s Age: ',hos.Age)
        print('Patient\'s Gender: ',hos.Gender)
        print('Patient\'s DOB: ',hos.DOB)
        print('Patient\'s Address: ',hos.Address)
        print('Patient\'s Hospital Number: ',hos.Hospital_Number)
        
    #A Method to search the list for a Patient's Info
    
    def search(self, Hospital_Number):
            l = []
            readfile(patient_list)
            for x in patient_list:
                y = x.search()
                if y == Hospital_Number:
                    l.append(x.printobject())
            return l
    
     #A method to Delete Patient information
    def delete(self, hmb01):
        j = hos.search(hmb01)
        del patient_list[j]
        
    #A Method to Update a patient's list
    def update(self, hmb01, Na):
        j = hos.search(hmb01)
        NAME = Na
        patient_list[j].Name = NAME;
        
def main():
    a = Patient_Management_System()
    
    while (1):
        print('1. Enter Details to Accept Patient')
        print('2. Display Patient Details')
        print('3. Search Patient Info from Patient List')
        print('4. Delete Patient Info from List')
        print('5. Exit')
        
        b = int(input('\nEnter the number of your choice: '))
        if (b == 1):
            Name = input('Patient\'s Name: ')
            Age = input('Patient\'s Age: ')
            Gender = input('Patient\'s Gender: ')
            DOB = input('Patient\'s DOB: ')
            Address = input('Patient\'s Current Address: ')
            Hospital_Number = input('Patient\'s Hospital Number: ')
            patient_list = Patient_records(patient_list,Name,Age,Gender,DOB,Address,Hospital_Number)
            
        if (b == 2):
            a.display()
        if (b == 3):
            a.search()
        if (b == 4):
            a.Delete()
        if (b == 5):
            quit()

            
def storage(rec,Name,Age, Gender, DOB,Hospital_Number):
    rec.append(Patient_Management_System(rec,Name,Age, Gender, DOB,Hospital_Number))
    return rec
record = []

main()

# %%
### Using Class and Object, build a patient management system with the following attributes
# 1. Name 2. Age 3. Gender 4.DOB 5. Address 6. Hospital number 
# with the following Accept, Display, Search, Update, Delete

class Patient_Management_System:
    
    '''A Patient Management Systemsing Class and Object'''
      
    def __init__(self,Name='',Age='',Gender='',DOB='',Address='',Hospital_Number=''):
        self.Name = Name
        self.Age = Age
        self.Gender = Gender
        self.DOB = DOB
        self.Address = Address
        self.Hospital_Number = Hospital_Number
        
        
    #A Method to Accept New Patients and append them to a list  
    
    def accept(self,NAME,AGE,GENDER,DOB,ADDRESS,HOSPITAL_NUMBER):
        hos = Patient_Management_System(self,NAME,AGE,GENDER,DOB,ADDRESS,HOSPITAL_NUMBER)
        patient_list.append(hos)
                 
                         
    #A Method to display Patient's information
    
    def display(self):
        print('============== PATIENT INFORMATION ===============')
        print('Patient details: ')
        print('Patient\'s Name: ',hos.Name)
        print('Patient\'s Age: ',hos.Age)
        print('Patient\'s Gender: ',hos.Gender)
        print('Patient\'s DOB: ',hos.DOB)
        print('Patient\'s Address: ',hos.Address)
        print('Patient\'s Hospital Number: ',hos.Hospital_Number)
        
    #A Method to search the list for a Patient's Info
    
    def search(self, Hospital_Number):
            l = []
            readfile(patient_list)
            for x in patient_list:
                y = x.search()
                if y == Hospital_Number:
                    l.append(x.printobject())
            return l
    
     #A method to Delete Patient information
    def delete(self, hmb01):
        j = hos.search(hmb01)
        del patient_list[j]
        
    #A Method to Update a patient's list
    def update(self, hmb01, Na):
        j = hos.search(hmb01)
        NAME = Na
        patient_list[j].Name = NAME;
 

    #An object of Patient_Management_System Class
patient_list = []
hos = Patient_Management_System('',0,'',0,0)

#Display Options for prompt guide
print('\nSELECT OPERATION YOU WISH TO PERFORM')
print('''\n1. Accept Patient Details
2. Display Patient Details
3. Search Patient Info from Patient List
4. Delete Patient Info from List
5. Exit
''')

#Enabling User to Choose an Operation
x = input('Please enter Y to edit details or N to Exit: ')
x = x.upper()

while x == 'Y':
    choice = int(input('Enter Operation No.: '))
    if (choice == 1):
        hos.accept('Ade',22,'M',10_09_2000,'HMB01')
        hos.accept('Ayo',23,'M',18_03_1999,'HMB02')
        hos.accept('Folu',21,'F',13_01_2001,'HMB03')
        hos.accept('Faith',24,'F',22_10_1998,'HMB04')
                     
    elif (choice == 2):
        print('\n')
        print('\nList of Patients\n')
        for i in range(patient_list.__len__()):
            hos.display(patient_list[i])
    elif (choice == 3):
        print('\nPatient Detail found: ')
        j = hos.search('Ayo')
        hos.display(patient_list[j])
        
    elif (choice == 4):
        hos.delete('Folu')
        print(patient_list.__len__())
        print('List of Patients after delete has been executed')
        for i in range(patient_list__len__()):
            hos.display(patient[i])
            
    elif (choice == 5):
        hos.update('Ade','Kalu')
        print(patient_list__len__())
        print('List of Patients after update has been executed')
        for i in range(patient_list__len__()):
            hos.display(patient[i])
        
    else:
        print('Please enter a valid Operation Number!!!')
    
    x = input('Please enter Y to edit details or N to Exit: ')
    x = x.upper()
    choice = int(input('Enter Operation No.: '))
    
n = 1
        
def main():
    a = Patient_Management_System()
    
    while (1):
        print('1. Enter Details to Accept Patient')
        print('2. Display Patient Details')
        print('3. Search Patient Info from Patient List')
        print('4. Delete Patient Info from List')
        print('5. Exit')
        
        b = int(input('\nEnter the number of your choice: '))
        if (b == 1):
            Name = input('Patient\'s Name: ')
            Age = input('Patient\'s Age: ')
            Gender = input('Patient\'s Gender: ')
            DOB = input('Patient\'s DOB: ')
            Address = input('Patient\'s Current Address: ')
            Hospital_Number = input('Patient\'s Hospital Number: ')
            patient_list = Patient_records(patient_list,Name,Age,Gender,DOB,Address,Hospital_Number)
            
        if (b == 2):
            a.display()
        if (b == 3):
            a.search()
        if (b == 4):
            a.Delete()
        if (b == 5):
            quit()

            
def storage(rec,Name,Age, Gender, DOB,Hospital_Number):
    rec.append(Patient_Management_System(rec,Name,Age, Gender, DOB,Hospital_Number))
    return rec
record = []

main()

# %%
from datetime import date

# %%
YOB = int(input('Enter year of birth: '))
#TS = Test SCore
CA = date.today().year - YOB

print(f'YOB: {YOB}')
print(f'CA: {CA}')

print('Answer true or false in every Qst')
print('''\nQst 1. Nigeria is an islamic state
Qst 2. There are 7 continents
Qst 3. Covid-19 was a scam
''')

qstn1 = input('Enter Qstn 1 Answer: ')
qstn2 = input('Enter Qstn 2 Answer: ')
qstn3 = input('Ente2000r Qstn 3 Answer: ')

if qstn1 == 'true' and qstn2 == 'true' and qstn3 == 'true':
    TS = 100 * 3
    print(TS)
elif qstn1 == 'false' and qstn2 == 'true' and qstn3 == 'true':
    TS = 100 * 2
elif qstn1 == 'true' and qstn2 == 'false' and qstn3 == 'true':
    TS = 100 * 2
elif qstn1 == 'true' and qstn2 == 'true' and qstn3 == 'false':
    TS = 100 *2
elif qstn1 == 'false' and qstn2 == 'false' and qstn3 == 'true':
    TS = 100 * 1
elif qstn1 == 'false' and qstn2 == 'true' and qstn3 == 'false':
    TS = 100 * 1
elif qstn1 == 'true' and qstn2 == 'false' and qstn3 == 'false':
    TS = 100 *1
elif qstn1 == 'false' and qstn2 == 'false' and qstn3 == 'false':
    TS = 1
    
print(f'TS: {TS}')    
print(f'CA: {CA}')

MA = TS/100 * CA
print(f'MA: {MA}')

IQ = MA/CA * 100

print(f'IQ: {IQ}')
# Out:
# Enter year of birth: 1990
# YOB: 1990
# CA: 32
# Answer true or false in every Qst
#
# Qst 1. Nigeria is an islamic state
# Qst 2. There are 7 continents
# Qst 3. Covid-19 was a scam
#
# Enter Qstn 1 Answer: true
# Enter Qstn 2 Answer: false
# Ente2000r Qstn 3 Answer: true
# TS: 200
# CA: 32
# MA: 64.0
# IQ: 200.0
